# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C://Users//Matth//OneDrive//Documents//Data Science//DATA 557//557_Final_Project//Data//DataScienceData.csv')
pop =  pd.read_csv('C://Users//Matth//OneDrive//Documents//Data Science//DATA 557//557_Final_Project//Data//pop_dense.csv', header=None, encoding="ISO-8859-1")
pop_dense = []
val = pop.values
country_dense = {}
for v in val:
    country_dense[v[0]] = v[1]
for i in range(0,len(data)):
    country = data.iloc[i][3]
    country = str(country)
    if country != "Other" and country != 'nan':
        dense = country_dense[country]
        pop_dense.append(dense)
    else:
        #dense = country_dense[country]
        pop_dense.append(0)

# %%
density = pd.DataFrame({"Density": pop_dense})

# %%
df = pd.concat([data, density], axis=1, sort='False')
density.head()
# Out:
#    Density
# 0    261.1
# 1    620.6
# 2  18342.0
# 3      0.0
# 4      0.0

# %%
df = df.drop(columns="Unnamed: 0")

# %%
df.to_csv("C://Users//Matth//OneDrive//Documents//Data Science//DATA 557//557_Final_Project//Data//Data_Science_Density.csv")

# %%
data
# Out:
#        Unnamed: 0 CompensationCurrency GenderSelect    Country   Age  \
# 0               9                  AED       Female      Egypt  30.0
# 1               3                  AED         Male    Germany  38.0
# 2               4                  AED         Male  Hong Kong  20.0
# 3               1                  AED         Male      Other  42.0
# 4               5                  AED         Male      Other  32.0
# ...           ...                  ...          ...        ...   ...
# 16711       14681                  NaN          NaN        NaN   NaN
# 16712       14682                  NaN          NaN        NaN   NaN
# 16713       14683                  NaN          NaN        NaN   NaN
# 16714       14684                  NaN         Male        NaN   NaN
# 16715       14685                  NaN          NaN        NaN   NaN
#
#                          EmploymentStatus StudentStatus  \
# 0                      Employed full-time           NaN
# 1                      Employed full-time           NaN
# 2                      Employed part-time           NaN
# 3                      Employed full-time           NaN
# 4                      Employed full-time           NaN
# ...                                   ...           ...
# 16711                  Employed full-time           NaN
# 16712  Not employed, but looking for work           NaN
# 16713  Not employed, but looking for work           NaN
# 16714                 I prefer not to say           Yes
# 16715                 I prefer not to say            No
#
#                                      LearningDataScience CodeWriter  \
# 0                                                    NaN        Yes
# 1                                                    NaN        Yes
# 2                                                    NaN        Yes
# 3                                                    NaN        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 16711                                                NaN        Yes
# 16712                                                NaN        NaN
# 16713                                                NaN        NaN
# 16714  Yes, I'm focused on learning mostly data scien...        NaN
# 16715  Yes, I'm focused on learning mostly data scien...        NaN
#
#       CareerSwitcher  ... TitleFit  \
# 0                NaN  ...     Fine
# 1                NaN  ...     Fine
# 2                NaN  ...     Fine
# 3                NaN  ...     Fine
# 4                NaN  ...     Fine
# ...              ...  ...      ...
# 16711            NaN  ...      NaN
# 16712            NaN  ...      NaN
# 16713            NaN  ...      NaN
# 16714            NaN  ...      NaN
# 16715            NaN  ...      NaN
#
#                                      CurrentEmployerType  \
# 0                      Employed by college or university
# 1      Employed by a company that performs advanced a...
# 2      Employed by a company that doesn't perform adv...
# 3      Employed by professional services/consulting firm
# 4      Employed by professional services/consulting firm
# ...                                                  ...
# 16711  Employed by a company that doesn't perform adv...
# 16712                                                NaN
# 16713                                                NaN
# 16714                                                NaN
# 16715                                                NaN
#
#       DataScienceIdentitySelect         FormalEducation  \
# 0                           Yes         Doctoral degree
# 1                           Yes         Master's degree
# 2                            No       Bachelor's degree
# 3        Sort of (Explain more)         Master's degree
# 4                           Yes         Master's degree
# ...                         ...                     ...
# 16711                        No         Master's degree
# 16712                       Yes         Master's degree
# 16713                       NaN                     NaN
# 16714                        No  I prefer not to answer
# 16715                       Yes                     NaN
#
#                     MajorSelect            Tenure  \
# 0              A health science     6 to 10 years
# 1                           NaN      3 to 5 years
# 2              Computer Science  Less than a year
# 3              Computer Science     6 to 10 years
# 4                         Other      3 to 5 years
# ...                         ...               ...
# 16711          Computer Science     6 to 10 years
# 16712                       NaN      1 to 2 years
# 16713                       NaN               NaN
# 16714                       NaN               NaN
# 16715  I never declared a major               NaN
#
#       LanguageRecommendationSelect CompensationAmount  ExchangeRate(USA)  \
# 0                             Java                NaN           0.272256
# 1                                R                0.0           0.272256
# 2                                R                1.0           0.272256
# 3                                R            30000.0           0.272256
# 4                           Python            75000.0           0.272256
# ...                            ...                ...                ...
# 16711                          NaN                NaN                NaN
# 16712                          NaN                NaN                NaN
# 16713                          NaN                NaN                NaN
# 16714                          NaN                NaN                NaN
# 16715                          NaN                NaN                NaN
#
#        CompensationYearUSD
# 0                      NaN
# 1                 0.000000
# 2                 0.272256
# 3              8167.680000
# 4             20419.200000
# ...                    ...
# 16711                  NaN
# 16712                  NaN
# 16713                  NaN
# 16714                  NaN
# 16715                  NaN
#
# [16716 rows x 21 columns]
